# %% [markdown]
# <a href="https://colab.research.google.com/github/SUREN37/Time-series-Forecast/blob/recurrent_neural_network/recurrent_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
